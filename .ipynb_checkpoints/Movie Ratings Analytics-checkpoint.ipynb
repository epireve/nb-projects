# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/epireve/data.local/Exercise'

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'RTRating', 'AudienceRating',
       'Budget', 'ReleaseYear']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'RTRating', 'AudienceRating', 'Budget', 'ReleaseYear'], dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  RTRating  AudienceRating  Budget  \
# 0  (500) Days of Summer      Comedy        87              81       8
# 1            10,000 B.C.  Adventure         9              44     105
# 2             12 Rounds      Action        30              52      20
# 3              127 Hours  Adventure        93              84      18
# 4              17 Again      Comedy        55              70      20
#
#    ReleaseYear
# 0         2009
# 1         2008
# 2         2009
# 3         2010
# 4         2009

# %%
movies.describe() # Haha, funny. ReleaseYear not mean be a numeric.
# Out:
#          RTRating  AudienceRating      Budget  ReleaseYear
# count  559.000000      559.000000  559.000000   559.000000
# mean    47.309481       58.744186   50.236136  2009.152057
# std     26.413091       16.826887   48.731817     1.362632
# min      0.000000        0.000000    0.000000  2007.000000
# 25%     25.000000       47.000000   20.000000  2008.000000
# 50%     46.000000       58.000000   35.000000  2009.000000
# 75%     70.000000       72.000000   65.000000  2010.000000
# max     97.000000       96.000000  300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# RTRating          559 non-null int64
# AudienceRating    559 non-null int64
# Budget            559 non-null int64
# ReleaseYear       559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
# Turn ReleaseYear into a category

# %%
movies.Film
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.describe()
# Out:
#          RTRating  AudienceRating      Budget  ReleaseYear
# count  559.000000      559.000000  559.000000   559.000000
# mean    47.309481       58.744186   50.236136  2009.152057
# std     26.413091       16.826887   48.731817     1.362632
# min      0.000000        0.000000    0.000000  2007.000000
# 25%     25.000000       47.000000   20.000000  2008.000000
# 50%     46.000000       58.000000   35.000000  2009.000000
# 75%     70.000000       72.000000   65.000000  2010.000000
# max     97.000000       96.000000  300.000000  2011.000000

# %%
movies.head()
# Out:
#                     Film      Genre  RTRating  AudienceRating  Budget  \
# 0  (500) Days of Summer      Comedy        87              81       8
# 1            10,000 B.C.  Adventure         9              44     105
# 2             12 Rounds      Action        30              52      20
# 3              127 Hours  Adventure        93              84      18
# 4              17 Again      Comedy        55              70      20
#
#    ReleaseYear
# 0         2009
# 1         2008
# 2         2009
# 3         2010
# 4         2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# RTRating          559 non-null int64
# AudienceRating    559 non-null int64
# Budget            559 non-null int64
# ReleaseYear       559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 27.4+ KB

# %%
movies.Film = movies.Genre.astype('category')
movies.Film = movies.ReleaseYear.astype('category')

# %%
movies.columns = ['Film', 'Genre', 'RTRating', 'AudienceRating',
       'Budget', 'Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# RTRating          559 non-null int64
# AudienceRating    559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 22.5+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'RTRating', 'AudienceRating', 'Budget', 'Year'], dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# RTRating          559 non-null int64
# AudienceRating    559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 22.5+ KB

# %%
# Funny why it did not works before. Because I'd access the wrong object/columns LOL
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# RTRating          559 non-null int64
# AudienceRating    559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 15.0 KB

# %%
# Accessing catergories type of data
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movies.Film.cat.categories # Not sure why it fall on Genre instead..
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#          RTRating  AudienceRating      Budget
# count  559.000000      559.000000  559.000000
# mean    47.309481       58.744186   50.236136
# std     26.413091       16.826887   48.731817
# min      0.000000        0.000000    0.000000
# 25%     25.000000       47.000000   20.000000
# 50%     46.000000       58.000000   35.000000
# 75%     70.000000       72.000000   65.000000
# max     97.000000       96.000000  300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Jointplots

# %%
j = sns.jointplot(data=movies, x='RTRating', y='AudienceRating', size=10, )

# %%
j = sns.jointplot(data=movies, x='RTRating', y='AudienceRating', size=10, kind='hex')

# %% [markdown]
# # Chart 1

# %% [markdown]
# ---

# %%
# Histogram

# %%
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.RTRating, bins=15)

# %%
n1 = plt.hist(movies.RTRating, bins=15) #Seaborn

# %%
sns.set_style("white")
#sns.set_style("darkgrid")
n2 = plt.hist(movies.AudienceRating, bins=15) #Seaborn

# %% [markdown]
# ---

# %% [markdown]
# ## Stacked Histograms

# %%
plt.hist(movies.Budget)
plt.show() # dont show addtional information

# %%
plt.hist(movies[movies.Genre == 'Action'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Drama'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Horror'].Budget, bins=15)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
plt.hist([movies[movies.Genre == 'Action'].Budget , \
          movies[movies.Genre == 'Action'].Budget], \
         stacked=True, bins=15)
plt.show()

# %%
# What about a bit of refactoring and encapsulation?
def myplot(genrelist):
    for name in genrelist:
        plt.hist(movies[movies.Genre == name].Budget, stacked=True, bins=15)
    plt.show()

# %%
myplot(['Action','Drama','Thriller']) #Plot working, but can't stacked

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
# Lets combining the list using append()
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].Budget)
    mylabels.append(gen)

h = plt.hist(list1, stacked=True, bins=30, rwidth=1, label=mylabels) #rwidth to close the gap
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Kernel Density Estimation (KDE) plot

# %%
vis1 = sns.lmplot(data=movies, x='RTRating', y='AudienceRating', fit_reg=False, hue='Genre', size=7, aspect=1)

# %%
k1 = sns.kdeplot(movies.RTRating, movies.AudienceRating, cmap='Reds') # line to add definition to map
k1b = sns.kdeplot(movies.RTRating, movies.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')

# %%
sns.set_style("dark")
k2 = sns.kdeplot(movies.Budget, movies.AudienceRating)

# %%
k2b = sns.kdeplot(movies.Budget, movies.RTRating)

# %%
f, axes = plt.subplots (1,2, figsize=(12,6))
k2 = sns.kdeplot(movies.Budget, movies.AudienceRating, ax=axes[0])
k3 = sns.kdeplot(movies.Budget, movies.RTRating, ax=axes[1])

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d23ef60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d3ac080>], dtype=object)
